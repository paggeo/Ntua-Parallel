# %%
with open('/home/georgepag4028/Desktop/Sxoli/Ntua-Parallel/a1/test64.out') as f64:
    lines64 = [line.rstrip() for line in f64]
with open('/home/georgepag4028/Desktop/Sxoli/Ntua-Parallel/a1/test1024.out') as f1024:
    lines1024 = [line.rstrip() for line in f1024]
with open('/home/georgepag4028/Desktop/Sxoli/Ntua-Parallel/a1/test4096.out') as f4096:
    lines4096 = [line.rstrip() for line in f4096]
tmp = []
res64 = []
for i in lines64:
    tmp = i.split()
    res64.append(float(tmp[-1]))
tmp = []
res1024 = []
for i in lines1024:
    tmp = i.split()
    res1024.append(float(tmp[-1]))
tmp = []
res4096 = []
for i in lines4096:
    tmp = i.split()
    res4096.append(float(tmp[-1]))

# %%
print(res64)
print(res1024)
print(res4096)
# Out:
# [0.023131, 0.013638, 0.009558, 0.008849, 0.56381]
# [10.961416, 5.458656, 2.741745, 1.856902, 6.139809]
# [175.851115, 88.313254, 44.92865, 35.358168, 40.694559]

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,4,6,8])
y = np.array(res64)*1000

plt.plot(x, y,marker = 'o')

plt.title("Game_of_Life 64x64")
plt.xlabel("Number of Threads")
plt.ylabel("Time(ms)")
plt.grid()

plt.show()
x = np.array([1,2,4,6,8])
y = np.array(res1024)

plt.plot(x, y,marker = 'o')

plt.title("Game_of_Life 1024x1024")
plt.xlabel("Number of Threads")
plt.ylabel("Time(s)")
plt.grid()

plt.show()
x = np.array([1,2,4,6,8])
y = np.array(res4096)

plt.plot(x, y,marker = 'o')

plt.title("Game_of_Life 4096x4096")
plt.xlabel("Number of Threads")
plt.ylabel("Time(s)")
plt.grid()

plt.show()
